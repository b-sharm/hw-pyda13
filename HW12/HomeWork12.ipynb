# %% [markdown]
# # Домашнее задание №11.
# ## Библиотека pandas
# **Выполнил: Шармашкеев Б.В.**

# %%
import pandas as pd

# %% [markdown]
# ### Задание 1.
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг

# %% [markdown]
# #### Загрузка данных и обзор дата фреймов

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
def ratings_classification(rating):
    if rating <= 2:
        return 'низкий'
    elif 2 < rating <= 4:
        return 'средний'
    else:
        return 'высокий'

# %%
ratings_flt = ratings.drop(columns={'userId', 'timestamp'}).groupby('movieId').mean()
ratings_flt['rating_class'] = ratings_flt['rating'].apply(ratings_classification)
ratings_flt.merge(movies.drop(columns='genres'), on='movieId', how='left').head(30)
# Out:
#     movieId    rating rating_class  \
# 0         1  3.872470      средний
# 1         2  3.401869      средний
# 2         3  3.161017      средний
# 3         4  2.384615      средний
# 4         5  3.267857      средний
# 5         6  3.884615      средний
# 6         7  3.283019      средний
# 7         8  3.800000      средний
# 8         9  3.150000      средний
# 9        10  3.450820      средний
# 10       11  3.689024      средний
# 11       12  2.861111      средний
# 12       13  3.937500      средний
# 13       14  3.451613      средний
# 14       15  2.318182      средний
# 15       16  3.948864      средний
# 16       17  3.924419      средний
# 17       18  3.288462      средний
# 18       19  2.597826      средний
# 19       20  2.538462      средний
# 20       21  3.536842      средний
# 21       22  3.355263      средний
# 22       23  3.090909      средний
# 23       24  3.044118      средний
# 24       25  3.742574      средний
# ...

# %% [markdown]
# ### Задание 2.
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
# ```python
# geo_data = {
#     'Центр': ['москва', 'тула', 'ярославль'],
#
#     'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
#     'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# ```
# Результат классификации запишите в отдельный столбец region.

# %%
keywords = pd.read_csv('keywords.csv')
keywords.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
def region_add(keyword):
    geo_data = {
    'Центр': ['москва', 'тула', 'ярославль'],
    'Северо-Запад': ['петербург', 'псков', 'мурманск'],
    'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
    }
    if keyword in geo_data['Центр']:
        return 'Центр'
    elif keyword in geo_data['Северо-Запад']:
        return 'Северо-Запад'
    elif keyword in geo_data['Дальний Восток']:
        return 'Дальний Восток'
    else:
        return 'undefined'

# %%
keywords['region'] = keywords['keyword'].apply(region_add)
keywords.head()
# Out:
#          keyword     shows     region
# 0             вк  64292779  undefined
# 1  одноклассники  63810309  undefined
# 2          порно  41747114  undefined
# 3           ютуб  39995567  undefined
# 4      вконтакте  21014195  undefined

# %%
keywords[(keywords['region'] != 'undefined')]
# Out:
#            keyword   shows          region
# 1259        москва  153050           Центр
# 5858   владивосток   43038  Дальний Восток
# 6075     ярославль   41720           Центр
# 8977      мурманск   29984    Северо-Запад
# 9084     хабаровск   29655  Дальний Восток
# 11222        псков   24885    Северо-Запад
# 11785         тула   23898           Центр
# 20823    петербург   14859    Северо-Запад
# 21445      сахалин   14494  Дальний Восток

# %% [markdown]
# ### Задание 3.
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из прошлого домашнего занятия (файл ratings.csv из базы https://grouplens.org/datasets/movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
# 1. В переменную years запишите список из всех годов с 1950 по 2010.
# 2. Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#     - для каждой строки пройдите по всем годам списка years
#     - если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
#     - если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# 3. Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
# 4. Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга

# %%
import numpy as np
import re

# %%
years = [i for i in range(1950, 2011)]

# %%
pattern = r'(\d{4})'
int(re.search(pattern, 'Toy Story (1995)')[0])
# Out:
# 1995

# %%
"""
В файле есть фильмы новее 2010, но в задании мы им выставляем 1900, так как в списке years их не будет.
Странный эксперимент получается =)
"""
def production_year(title):
    f = re.findall(r'(\d{4})', title)
    if not f:
        return 1900
    else:
        py = int(f[0])
        if py in years:
            return py
        else:
            return 1900

# %%
movies['year'] = movies['title'].apply(production_year)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
df = ratings[['movieId', 'rating']].merge(movies[['movieId', 'year']], on='movieId', how='left').groupby('year').mean()
df.sort_values('rating', ascending=False).head(50)
# Out:
#            movieId    rating
# year
# 1957   2750.965190  4.014241
# 1972   3983.538976  4.011136
# 1952   4107.796053  4.000000
# 1974   3981.137476  3.999058
# 1954   2867.661850  3.994220
# 1951   2605.588477  3.983539
# 1962   3479.100543  3.952446
# 1950   3503.427966  3.915254
# 1977   3604.516320  3.905786
# 1964   3557.843823  3.841492
# 1959   2530.706522  3.841033
# 1958   2574.500000  3.823171
# 1969   4767.897163  3.817376
# 1967   4331.990783  3.814516
# 1975   2888.126214  3.814147
# 1960   3740.934211  3.809211
# 1976   4203.925690  3.806794
# 1973   4400.295238  3.806667
# 1979   3024.523269  3.783201
# 1981   2405.406186  3.758763
# 1953   4032.321101  3.754587
# 1971   3207.001570  3.753532
# 1955   4925.548276  3.751724
# 1966  10001.274336  3.736726
# 1980   3035.566340  3.708816
# 1963   3760.778409  3.705966
# 1970   6068.918644  3.700000
# 1968   3658.562857  3.685714
# 1965   5132.618474  3.678715
# 1961   3721.304054  3.663851
# 1983   3710.885714  3.657635
# ...
