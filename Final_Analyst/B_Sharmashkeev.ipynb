# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
p1g = pd.read_csv('Plant_1_Generation_Data.csv')
p1g['DATE_TIME'] = pd.to_datetime(p1g['DATE_TIME'], format='%d-%m-%Y %H:%M')
p1g.head()
# Out:
#    DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0 2020-05-15   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 1 2020-05-15   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 2 2020-05-15   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
# 3 2020-05-15   4135001  7JYdWkrLSPkdwr4       0.0       0.0          0.0
# 4 2020-05-15   4135001  McdE0feGgRqW7Ca       0.0       0.0          0.0
#
#    TOTAL_YIELD
# 0    6259559.0
# 1    6183645.0
# 2    6987759.0
# 3    7602960.0
# 4    7158964.0

# %%
p1g[(p1g['DATE_TIME'].between('2020-05-20 22:45:00', '2020-05-21 07:45:00'))]
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 11752 2020-05-20 22:45:00   4135001  1BY6WEcLGh8j5v7      0.00     0.000
# 11753 2020-05-20 22:45:00   4135001  1IF53ai7Xc0U56Y      0.00     0.000
# 11754 2020-05-20 22:45:00   4135001  3PZuoBAID5Wc2HD      0.00     0.000
# 11755 2020-05-20 22:45:00   4135001  7JYdWkrLSPkdwr4      0.00     0.000
# 11756 2020-05-20 22:45:00   4135001  McdE0feGgRqW7Ca      0.00     0.000
# 11757 2020-05-20 22:45:00   4135001  VHMLBKoKgIrUVDU      0.00     0.000
# 11758 2020-05-20 22:45:00   4135001  WRmjgnKYAwPKWDb      0.00     0.000
# 11759 2020-05-20 22:45:00   4135001  YxYtjZvoooNbGkE      0.00     0.000
# 11760 2020-05-20 22:45:00   4135001  ZnxXDlPa8U1GXgE      0.00     0.000
# 11761 2020-05-20 22:45:00   4135001  ZoEaEvLYb1n2sOq      0.00     0.000
# 11762 2020-05-20 22:45:00   4135001  adLQvlD726eNBSB      0.00     0.000
# 11763 2020-05-20 22:45:00   4135001  bvBOhCH3iADSZry      0.00     0.000
# ...

# %% [markdown]
# Отсутствуют данные по выработке энергии с 23:00 20 мая 2020 до 07:45 21 мая 2020

# %%
p1w = pd.read_csv('Plant_1_Weather_Sensor_Data.csv')
p1w['DATE_TIME'] = pd.to_datetime(p1w['DATE_TIME'], format='%Y-%m-%d %H:%M:%S')
p1w.head()
# Out:
#             DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0 2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1 2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2 2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3 2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4 2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %%
p1_joined = p1w.merge(p1gg, on='DATE_TIME', how='inner')
p1_joined.head(50)
# Out:
#              DATE_TIME  PLANT_ID_x       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00     4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00     4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00     4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00     4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00     4135001  HmiyD2TTLFNqkNe            24.621525
# 5  2020-05-15 01:15:00     4135001  HmiyD2TTLFNqkNe            24.536092
# 6  2020-05-15 01:30:00     4135001  HmiyD2TTLFNqkNe            24.638674
# 7  2020-05-15 01:45:00     4135001  HmiyD2TTLFNqkNe            24.873022
# 8  2020-05-15 02:00:00     4135001  HmiyD2TTLFNqkNe            24.936930
# 9  2020-05-15 02:15:00     4135001  HmiyD2TTLFNqkNe            25.012248
# 10 2020-05-15 02:30:00     4135001  HmiyD2TTLFNqkNe            25.005149
# 11 2020-05-15 02:45:00     4135001  HmiyD2TTLFNqkNe            24.993020
# ...

# %%
p1_joined[(p1_joined['DC_POWER'].isnull())]
# Out:
# Empty DataFrame
# Columns: [DATE_TIME, PLANT_ID_x, SOURCE_KEY, AMBIENT_TEMPERATURE, MODULE_TEMPERATURE, IRRADIATION, PLANT_ID_y, DC_POWER, AC_POWER, DAILY_YIELD, TOTAL_YIELD]
# Index: []

# %%
p1w.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652
